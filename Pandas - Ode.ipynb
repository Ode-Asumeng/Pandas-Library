# %%
#importing pandas library
import pandas as pd

# %% [markdown]
# ## DataFrame

# %%
votes = pd.DataFrame({'Yes':[45,53], 'No':[40,40]})
print(votes)
# Out:
#    Yes  No
# 0   45  40
# 1   53  40

# %%
pd.DataFrame({'Bob':['I liked it.','It was awful.'],'Sue':['Pretty good.','Bland.']}, index = ['Main Dish','Dessert'])
# Out:
#                      Bob           Sue
# Main Dish    I liked it.  Pretty good.
# Dessert    It was awful.        Bland.

# %% [markdown]
# ## Series

# %%
pd.Series([1,2,3,4,5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
total = 10 + 20
print(total)
# Out:
# 30

# %%
total
# Out:
# 30

# %%
#loading data
wine_data = pd.read_csv('wine-data-Thu_2_6_22.csv')

# %%
wine_data
# Out:
#         Column1   country                                        description  \
# 0             0     Italy  Aromas include tropical fruit, broom, brimston...
# 1             1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2             2        US  Tart and snappy, the flavors of lime flesh and...
# 3             3        US  Pineapple rind, lemon pith and orange blossom ...
# 4             4        US  Much like the regular bottling from 2012, this...
# ...         ...       ...                                                ...
# 129966   129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967   129967        US  Citation is given as much as a decade of bottl...
# 129968   129968    France  Well-drained gravel soil gives this wine its c...
# 129969   129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970   129970    France  Big, rich and off-dry, this is powered by inte...
#
# ...

# %%
wine_data.shape
# Out:
# (129971, 14)

# %%
#to get your row
wine_data.shape[0]
# Out:
# 129971

# %%
#to see the head of your data 
wine_data.head(10)
# Out:
#    Column1   country                                        description  \
# 0        0     Italy  Aromas include tropical fruit, broom, brimston...
# 1        1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        2        US  Tart and snappy, the flavors of lime flesh and...
# 3        3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        4        US  Much like the regular bottling from 2012, this...
# 5        5     Spain  Blackberry and raspberry aromas show a typical...
# 6        6     Italy  Here's a bright, informal red that opens with ...
# 7        7    France  This dry and restrained wine offers spice in p...
# 8        8   Germany  Savory dried thyme notes accent sunnier flavor...
# 9        9    France  This has great depth of flavor with its fresh ...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# ...

# %%
#to see the end of your data
wine_data.tail()
# Out:
#         Column1  country                                        description  \
# 129966   129966  Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967   129967       US  Citation is given as much as a decade of bottl...
# 129968   129968   France  Well-drained gravel soil gives this wine its c...
# 129969   129969   France  A dry style of Pinot Gris, this is crisp with ...
# 129970   129970   France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price province  \
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0    Mosel
# 129967                                     NaN      90   75.0   Oregon
# 129968                                   Kritt      90   30.0   Alsace
# 129969                                     NaN      90   32.0   Alsace
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace
#
#        region_1      region_2         taster_name taster_twitter_handle  \
# ...

# %%
#indexing 
wine_data['country'].head()
# Out:
# 0       Italy
# 1    Portugal
# 2          US
# 3          US
# 4          US
# Name: country, dtype: object

# %%
#to get a specific value in the data
wine_data['country'][5]
# Out:
# 'Spain'

# %% [markdown]
# ## Indexing in Pandas

# %%
#index-based selection - iloc
#label based selection - loc

# %%
#iloc
wine_data.iloc[:3,1]
# Out:
# 0       Italy
# 1    Portugal
# 2          US
# Name: country, dtype: object

# %%
wine_data.iloc[0,4]
# Out:
# 87

# %%
wine_data.iloc[0,1] #[row:column]
# Out:
# 'Italy'

# %%
wine_data.iloc[:3,1:4] #indexes are exclusive
# Out:
#     country                                        description   designation
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
# 2        US  Tart and snappy, the flavors of lime flesh and...           NaN

# %%
wine_data.loc[:4, 'country']
# Out:
# 0       Italy
# 1    Portugal
# 2          US
# 3          US
# 4          US
# Name: country, dtype: object

# %%
wine_data.loc[0,'country']
# Out:
# 'Italy'

# %% [markdown]
# ## Manipulating the index

# %%
#you can manipulate the index. You use set_index() method to do this

# %%
wine_data.set_index('country')
# Out:
#           Column1                                        description  \
# country
# Italy           0  Aromas include tropical fruit, broom, brimston...
# Portugal        1  This is ripe and fruity, a wine that is smooth...
# US              2  Tart and snappy, the flavors of lime flesh and...
# US              3  Pineapple rind, lemon pith and orange blossom ...
# US              4  Much like the regular bottling from 2012, this...
# ...           ...                                                ...
# Germany    129966  Notes of honeysuckle and cantaloupe sweeten th...
# US         129967  Citation is given as much as a decade of bottl...
# France     129968  Well-drained gravel soil gives this wine its c...
# France     129969  A dry style of Pinot Gris, this is crisp with ...
# France     129970  Big, rich and off-dry, this is powered by inte...
#
#                                      designation  points  price  \
# country
# ...

# %%
#Conditional Selection

wine_data.country == 'Italy'
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 129966    False
# 129967    False
# 129968    False
# 129969    False
# 129970    False
# Name: country, Length: 129971, dtype: bool

# %%
wine_data.loc[wine_data.country == 'France']
# Out:
#         Column1 country                                        description  \
# 7             7  France  This dry and restrained wine offers spice in p...
# 9             9  France  This has great depth of flavor with its fresh ...
# 11           11  France  This is a dry wine, very spicy, with a tight, ...
# 30           30  France  Red cherry fruit comes laced with light tannin...
# 42           42  France  This is a festive wine, with soft, ripe fruit ...
# ...         ...     ...                                                ...
# 129964   129964  France  Initially quite muted, this wine slowly develo...
# 129965   129965  France  While it's rich, this beautiful dry wine also ...
# 129968   129968  France  Well-drained gravel soil gives this wine its c...
# 129969   129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129970   129970  France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price    province  \
# ...

# %%
wine_data.loc[wine_data.designation=='Nouveau']
# Out:
#         Column1 country                                        description  \
# 30           30  France  Red cherry fruit comes laced with light tannin...
# 42           42  France  This is a festive wine, with soft, ripe fruit ...
# 2431       2431  France  This has surprisingly structured fruits and fi...
# 7646       7646  France  Henry Fessy's can-can dancer is with us again ...
# 9291       9291  France  In keeping with the good quality of 2015's Bea...
# 12499     12499  France  This is a festive wine, with soft, ripe fruit ...
# 13517     13517  France  Soft and richly fruity, this has all the right...
# 14275     14275  France  This is a classic, bold, fruity Nouveau, with ...
# 18333     18333  France  The wine has a bitter edge with a burnt charac...
# 22583     22583  France  Bright red fruits in this attractive cherry an...
# 22587     22587  France  Excellent color on this firmly fruity wine. It...
# ...

# %%
#wine_data.loc[wine_data.country==['Italy','US']]

# %%
wine_data.loc[wine_data.country=='Italy'].head()
# Out:
#     Column1 country                                        description  \
# 0         0   Italy  Aromas include tropical fruit, broom, brimston...
# 6         6   Italy  Here's a bright, informal red that opens with ...
# 13       13   Italy  This is dominated by oak and oak-driven aromas...
# 22       22   Italy  Delicate aromas recall white flower and citrus...
# 24       24   Italy  Aromas of prune, blackcurrant, toast and oak c...
#
#      designation  points  price           province  region_1 region_2  \
# 0   Vulkà Bianco      87    NaN  Sicily & Sardinia      Etna      NaN
# 6        Belsito      87   16.0  Sicily & Sardinia  Vittoria      NaN
# 13         Rosso      87    NaN  Sicily & Sardinia      Etna      NaN
# 22     Ficiligno      87   19.0  Sicily & Sardinia   Sicilia      NaN
# 24         Aynat      87   35.0  Sicily & Sardinia   Sicilia      NaN
#
#       taster_name taster_twitter_handle  \
# 0   Kerin O’Keefe          @kerinokeefe
# ...

# %%
wine_data.loc[wine_data.designation.notnull()]
# Out:
#         Column1   country                                        description  \
# 0             0     Italy  Aromas include tropical fruit, broom, brimston...
# 1             1  Portugal  This is ripe and fruity, a wine that is smooth...
# 3             3        US  Pineapple rind, lemon pith and orange blossom ...
# 4             4        US  Much like the regular bottling from 2012, this...
# 5             5     Spain  Blackberry and raspberry aromas show a typical...
# ...         ...       ...                                                ...
# 129964   129964    France  Initially quite muted, this wine slowly develo...
# 129965   129965    France  While it's rich, this beautiful dry wine also ...
# 129966   129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129968   129968    France  Well-drained gravel soil gives this wine its c...
# 129970   129970    France  Big, rich and off-dry, this is powered by inte...
#
# ...

# %%
wine_data.loc[wine_data.designation.isnull()]
# Out:
#         Column1      country  \
# 2             2           US
# 7             7       France
# 11           11       France
# 12           12           US
# 14           14           US
# ...         ...          ...
# 129952   129952           US
# 129955   129955  New Zealand
# 129961   129961        Italy
# 129967   129967           US
# 129969   129969       France
#
#                                               description designation  points  \
# 2       Tart and snappy, the flavors of lime flesh and...         NaN      87
# 7       This dry and restrained wine offers spice in p...         NaN      87
# 11      This is a dry wine, very spicy, with a tight, ...         NaN      87
# 12      Slightly reduced, this wine offers a chalky, t...         NaN      87
# 14      Building on 150 years and six generations of w...         NaN      87
# ...                                                   ...         ...     ...
# ...

# %% [markdown]
# ## Assigning data

# %%
wine_data['date'] = '3/10/2021'

# %%
wine_data['date']
# Out:
# 0         3/10/2021
# 1         3/10/2021
# 2         3/10/2021
# 3         3/10/2021
# 4         3/10/2021
#             ...
# 129966    3/10/2021
# 129967    3/10/2021
# 129968    3/10/2021
# 129969    3/10/2021
# 129970    3/10/2021
# Name: date, Length: 129971, dtype: object

# %% [markdown]
# ## Summary Fuctions

# %%
#describe method
# gives a summary of the statistics of a table
wine_data.price.describe()
# Out:
# count    120975.000000
# mean         35.363389
# std          41.022218
# min           4.000000
# 25%          17.000000
# 50%          25.000000
# 75%          42.000000
# max        3300.000000
# Name: price, dtype: float64

# %%
wine_data.description.describe()
# Out:
# count                                                129971
# unique                                               119955
# top       Cigar box, café au lait, and dried tobacco aro...
# freq                                                      3
# Name: description, dtype: object

# %%
#.unique()brings out the unique values of a table
wine_data.taster_name.unique()
# Out:
# array(['Kerin O’Keefe', 'Roger Voss', 'Paul Gregutt',
#        'Alexander Peartree', 'Michael Schachner', 'Anna Lee C. Iijima',
#        'Virginie Boone', 'Matt Kettmann', nan, 'Sean P. Sullivan',
#        'Jim Gordon', 'Joe Czerwinski', 'Anne Krebiehl\xa0MW',
#        'Lauren Buzzeo', 'Mike DeSimone', 'Jeff Jenssen',
#        'Susan Kostrzewa', 'Carrie Dykes', 'Fiona Adams',
#        'Christina Pickard'], dtype=object)

# %%
wine_data.country.unique()
# Out:
# array(['Italy', 'Portugal', 'US', 'Spain', 'France', 'Germany',
#        'Argentina', 'Chile', 'Australia', 'Austria', 'South Africa',
#        'New Zealand', 'Israel', 'Hungary', 'Greece', 'Romania', 'Mexico',
#        'Canada', nan, 'Turkey', 'Czech Republic', 'Slovenia',
#        'Luxembourg', 'Croatia', 'Georgia', 'Uruguay', 'England',
#        'Lebanon', 'Serbia', 'Brazil', 'Moldova', 'Morocco', 'Peru',
#        'India', 'Bulgaria', 'Cyprus', 'Armenia', 'Switzerland',
#        'Bosnia and Herzegovina', 'Ukraine', 'Slovakia', 'Macedonia',
#        'China', 'Egypt'], dtype=object)

# %%
#wine_data.drop('country')

# %%
wine_data.taster_name.value_counts()
# Out:
# Roger Voss            25514
# Michael Schachner     15134
# Kerin O’Keefe         10776
# Virginie Boone         9537
# Paul Gregutt           9532
# Matt Kettmann          6332
# Joe Czerwinski         5147
# Sean P. Sullivan       4966
# Anna Lee C. Iijima     4415
# Jim Gordon             4177
# Anne Krebiehl MW       3685
# Lauren Buzzeo          1835
# Susan Kostrzewa        1085
# Mike DeSimone           514
# Jeff Jenssen            491
# Alexander Peartree      415
# Carrie Dykes            139
# Fiona Adams              27
# Christina Pickard         6
# Name: taster_name, dtype: int64

# %%
wine_data.taster_name.value_counts(ascending=True)
#we use ascending=True to get from lowest to highest . The default is highest to lowest
# Out:
# Christina Pickard         6
# Fiona Adams              27
# Carrie Dykes            139
# Alexander Peartree      415
# Jeff Jenssen            491
# Mike DeSimone           514
# Susan Kostrzewa        1085
# Lauren Buzzeo          1835
# Anne Krebiehl MW       3685
# Jim Gordon             4177
# Anna Lee C. Iijima     4415
# Sean P. Sullivan       4966
# Joe Czerwinski         5147
# Matt Kettmann          6332
# Paul Gregutt           9532
# Virginie Boone         9537
# Kerin O’Keefe         10776
# Michael Schachner     15134
# Roger Voss            25514
# Name: taster_name, dtype: int64

# %% [markdown]
# ## Grouping

# %%
#groupby() is used when we want to group our data

# %%
wine_data.groupby('country') #you do not need to run this code before putting max,min or average

# %%
wine_data.groupby('country').price.max()
# Out:
# country
# Argentina                  230.0
# Armenia                     15.0
# Australia                  850.0
# Austria                   1100.0
# Bosnia and Herzegovina      13.0
# Brazil                      60.0
# Bulgaria                   100.0
# Canada                     120.0
# Chile                      400.0
# China                       18.0
# Croatia                     65.0
# Cyprus                      21.0
# Czech Republic              45.0
# Egypt                        NaN
# England                     95.0
# France                    3300.0
# Georgia                     40.0
# Germany                    775.0
# Greece                      79.0
# Hungary                    764.0
# India                       20.0
# Israel                     150.0
# Italy                      900.0
# Lebanon                     75.0
# Luxembourg                  30.0
# Macedonia                   20.0
# Mexico                     108.0
# Moldova                     42.0
# ...

# %%
wine_data.groupby('country').price.mean()
# Out:
# country
# Argentina                 24.510117
# Armenia                   14.500000
# Australia                 35.437663
# Austria                   30.762772
# Bosnia and Herzegovina    12.500000
# Brazil                    23.765957
# Bulgaria                  14.645390
# Canada                    35.712598
# Chile                     20.786458
# China                     18.000000
# Croatia                   25.450704
# Cyprus                    16.272727
# Czech Republic            24.250000
# Egypt                           NaN
# England                   51.681159
# France                    41.139120
# Georgia                   19.321429
# Germany                   42.257547
# Greece                    22.364425
# Hungary                   40.648276
# India                     13.333333
# Israel                    31.768916
# Italy                     39.663770
# Lebanon                   30.685714
# Luxembourg                23.333333
# Macedonia                 15.583333
# ...

# %%
wine_data.groupby('country').points.max()
# Out:
# country
# Argentina                  97
# Armenia                    88
# Australia                 100
# Austria                    98
# Bosnia and Herzegovina     88
# Brazil                     89
# Bulgaria                   91
# Canada                     94
# Chile                      95
# China                      89
# Croatia                    91
# Cyprus                     89
# Czech Republic             89
# Egypt                      84
# England                    95
# France                    100
# Georgia                    92
# Germany                    98
# Greece                     93
# Hungary                    97
# India                      93
# Israel                     94
# Italy                     100
# Lebanon                    91
# Luxembourg                 90
# Macedonia                  89
# Mexico                     92
# Moldova                    91
# Morocco                    93
# New Zealand                95
# ...

# %%
wine_data.groupby(['country','price'])

# %% [markdown]
# ### Method aggregates

# %%
#gives us a summary of prices

# %%
wine_data.groupby('country').price.agg([len,min,max,])
# Out:
#                             len   min     max
# country
# Argentina                3800.0   4.0   230.0
# Armenia                     2.0  14.0    15.0
# Australia                2329.0   5.0   850.0
# Austria                  3345.0   7.0  1100.0
# Bosnia and Herzegovina      2.0  12.0    13.0
# Brazil                     52.0  10.0    60.0
# Bulgaria                  141.0   8.0   100.0
# Canada                    257.0  12.0   120.0
# Chile                    4472.0   5.0   400.0
# China                       1.0  18.0    18.0
# Croatia                    73.0  12.0    65.0
# Cyprus                     11.0  11.0    21.0
# Czech Republic             12.0  15.0    45.0
# Egypt                       1.0   NaN     NaN
# England                    74.0  25.0    95.0
# France                  22093.0   5.0  3300.0
# Georgia                    86.0   9.0    40.0
# Germany                  2165.0   5.0   775.0
# Greece                    466.0   8.0    79.0
# ...

# %%
wine_data.groupby(['country','province']).price.count() #do not understand
# Out:
# country    province
# Argentina  Mendoza Province    3226
#            Other                530
# Armenia    Armenia                2
# Australia  Australia Other      236
#            New South Wales       85
#                                ...
# Uruguay    Juanico               12
#            Montevideo            11
#            Progreso              11
#            San Jose               3
#            Uruguay               24
# Name: price, Length: 425, dtype: int64

# %%
wine_data.groupby(['country','price']).designation.agg(len)
# Out:
# country    price
# Argentina  4.0       1
#            5.0       3
#            6.0      11
#            7.0      19
#            8.0      54
#                     ..
# Uruguay    52.0      1
#            60.0      3
#            65.0      1
#            120.0     1
#            130.0     1
# Name: designation, Length: 2238, dtype: int64

# %%
wine_data.groupby(['country','province']).price.count().index
# Out:
# MultiIndex([('Argentina',  'Mendoza Province'),
#             ('Argentina',             'Other'),
#             (  'Armenia',           'Armenia'),
#             ('Australia',   'Australia Other'),
#             ('Australia',   'New South Wales'),
#             ('Australia',   'South Australia'),
#             ('Australia',          'Tasmania'),
#             ('Australia',          'Victoria'),
#             ('Australia', 'Western Australia'),
#             (  'Austria',           'Austria'),
#             ...
#             (       'US',        'Washington'),
#             (       'US', 'Washington-Oregon'),
#             (  'Ukraine',           'Ukraine'),
#             (  'Uruguay',         'Atlantida'),
#             (  'Uruguay',         'Canelones'),
#             (  'Uruguay',           'Juanico'),
#             (  'Uruguay',        'Montevideo'),
#             (  'Uruguay',          'Progreso'),
#             (  'Uruguay',          'San Jose'),
# ...

# %%
wine_data.groupby(['country']).price.count().index
# Out:
# Index(['Argentina', 'Armenia', 'Australia', 'Austria',
#        'Bosnia and Herzegovina', 'Brazil', 'Bulgaria', 'Canada', 'Chile',
#        'China', 'Croatia', 'Cyprus', 'Czech Republic', 'Egypt', 'England',
#        'France', 'Georgia', 'Germany', 'Greece', 'Hungary', 'India', 'Israel',
#        'Italy', 'Lebanon', 'Luxembourg', 'Macedonia', 'Mexico', 'Moldova',
#        'Morocco', 'New Zealand', 'Peru', 'Portugal', 'Romania', 'Serbia',
#        'Slovakia', 'Slovenia', 'South Africa', 'Spain', 'Switzerland',
#        'Turkey', 'US', 'Ukraine', 'Uruguay'],
#       dtype='object', name='country')

# %%
wine_data.groupby(['country'])

# %%
type(wine_data.groupby(['country','province']).price.count().index)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
wine_data.groupby(['country','province']).price.count().index
# Out:
# MultiIndex([('Argentina',  'Mendoza Province'),
#             ('Argentina',             'Other'),
#             (  'Armenia',           'Armenia'),
#             ('Australia',   'Australia Other'),
#             ('Australia',   'New South Wales'),
#             ('Australia',   'South Australia'),
#             ('Australia',          'Tasmania'),
#             ('Australia',          'Victoria'),
#             ('Australia', 'Western Australia'),
#             (  'Austria',           'Austria'),
#             ...
#             (       'US',        'Washington'),
#             (       'US', 'Washington-Oregon'),
#             (  'Ukraine',           'Ukraine'),
#             (  'Uruguay',         'Atlantida'),
#             (  'Uruguay',         'Canelones'),
#             (  'Uruguay',           'Juanico'),
#             (  'Uruguay',        'Montevideo'),
#             (  'Uruguay',          'Progreso'),
#             (  'Uruguay',          'San Jose'),
# ...

# %%
wine_data.groupby(['country']).price.count().reset_index()
# Out:
#                    country  price
# 0                Argentina   3756
# 1                  Armenia      2
# 2                Australia   2294
# 3                  Austria   2799
# 4   Bosnia and Herzegovina      2
# 5                   Brazil     47
# 6                 Bulgaria    141
# 7                   Canada    254
# 8                    Chile   4416
# 9                    China      1
# 10                 Croatia     71
# 11                  Cyprus     11
# 12          Czech Republic     12
# 13                   Egypt      0
# 14                 England     69
# 15                  France  17776
# 16                 Georgia     84
# 17                 Germany   2120
# 18                  Greece    461
# 19                 Hungary    145
# 20                   India      9
# 21                  Israel    489
# 22                   Italy  16914
# 23                 Lebanon     35
# 24              Luxembourg      6
# 25               Macedonia     12
# ...

# %% [markdown]
# ## Sorting

# %%
testing = wine_data.groupby(['country']).price.count().reset_index()
testing
# Out:
#                    country  price
# 0                Argentina   3756
# 1                  Armenia      2
# 2                Australia   2294
# 3                  Austria   2799
# 4   Bosnia and Herzegovina      2
# 5                   Brazil     47
# 6                 Bulgaria    141
# 7                   Canada    254
# 8                    Chile   4416
# 9                    China      1
# 10                 Croatia     71
# 11                  Cyprus     11
# 12          Czech Republic     12
# 13                   Egypt      0
# 14                 England     69
# 15                  France  17776
# 16                 Georgia     84
# 17                 Germany   2120
# 18                  Greece    461
# 19                 Hungary    145
# 20                   India      9
# 21                  Israel    489
# 22                   Italy  16914
# 23                 Lebanon     35
# 24              Luxembourg      6
# 25               Macedonia     12
# ...

# %%
testing.sort_values(by='country')
# Out:
#                    country  price
# 0                Argentina   3756
# 1                  Armenia      2
# 2                Australia   2294
# 3                  Austria   2799
# 4   Bosnia and Herzegovina      2
# 5                   Brazil     47
# 6                 Bulgaria    141
# 7                   Canada    254
# 8                    Chile   4416
# 9                    China      1
# 10                 Croatia     71
# 11                  Cyprus     11
# 12          Czech Republic     12
# 13                   Egypt      0
# 14                 England     69
# 15                  France  17776
# 16                 Georgia     84
# 17                 Germany   2120
# 18                  Greece    461
# 19                 Hungary    145
# 20                   India      9
# 21                  Israel    489
# 22                   Italy  16914
# 23                 Lebanon     35
# 24              Luxembourg      6
# 25               Macedonia     12
# ...

# %%
testing.sort_values(by='price')
# Out:
#                    country  price
# 13                   Egypt      0
# 34                Slovakia      1
# 9                    China      1
# 1                  Armenia      2
# 4   Bosnia and Herzegovina      2
# 24              Luxembourg      6
# 38             Switzerland      7
# 20                   India      9
# 11                  Cyprus     11
# 33                  Serbia     12
# 25               Macedonia     12
# 12          Czech Republic     12
# 41                 Ukraine     14
# 30                    Peru     16
# 28                 Morocco     28
# 23                 Lebanon     35
# 5                   Brazil     47
# 27                 Moldova     59
# 14                 England     69
# 26                  Mexico     70
# 10                 Croatia     71
# 35                Slovenia     80
# 16                 Georgia     84
# 39                  Turkey     90
# 42                 Uruguay    109
# 32                 Romania    120
# ...

# %% [markdown]
# ## DType

# %%
#dtype to check the type of data in a scpecific column

# %%
wine_data.points.dtype
# Out:
# dtype('int64')

# %%
wine_data.dtypes
# Out:
# Column1                    int64
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# date                      object
# dtype: object

# %% [markdown]
# ## Missing Data

# %%
#fillna fills empty cells

# %%
wine_data[pd.isnull(wine_data)['country']]
# Out:
#         Column1 country                                        description  \
# 913         913     NaN  Amber in color, this wine has aromas of peach ...
# 3131       3131     NaN  Soft, fruity and juicy, this is a pleasant, si...
# 4243       4243     NaN  Violet-red in color, this semisweet wine has a...
# 9509       9509     NaN  This mouthwatering blend starts with a nose of...
# 9750       9750     NaN  This orange-style wine has a cloudy yellow-gol...
# ...         ...     ...                                                ...
# 124176   124176     NaN  This Swiss red blend is composed of four varie...
# 129407   129407     NaN  Dry spicy aromas of dusty plum and tomato add ...
# 129408   129408     NaN  El Capricho is one of Uruguay's more consisten...
# 129590   129590     NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 129900   129900     NaN  This wine offers a delightful bouquet of black...
#
# ...

# %%
wine_data.loc[wine_data.country.isnull()]
# Out:
#         Column1 country                                        description  \
# 913         913     NaN  Amber in color, this wine has aromas of peach ...
# 3131       3131     NaN  Soft, fruity and juicy, this is a pleasant, si...
# 4243       4243     NaN  Violet-red in color, this semisweet wine has a...
# 9509       9509     NaN  This mouthwatering blend starts with a nose of...
# 9750       9750     NaN  This orange-style wine has a cloudy yellow-gol...
# ...         ...     ...                                                ...
# 124176   124176     NaN  This Swiss red blend is composed of four varie...
# 129407   129407     NaN  Dry spicy aromas of dusty plum and tomato add ...
# 129408   129408     NaN  El Capricho is one of Uruguay's more consisten...
# 129590   129590     NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 129900   129900     NaN  This wine offers a delightful bouquet of black...
#
# ...

# %%
wine_data
# Out:
#         Column1   country                                        description  \
# 0             0     Italy  Aromas include tropical fruit, broom, brimston...
# 1             1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2             2        US  Tart and snappy, the flavors of lime flesh and...
# 3             3        US  Pineapple rind, lemon pith and orange blossom ...
# 4             4        US  Much like the regular bottling from 2012, this...
# ...         ...       ...                                                ...
# 129966   129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967   129967        US  Citation is given as much as a decade of bottl...
# 129968   129968    France  Well-drained gravel soil gives this wine its c...
# 129969   129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970   129970    France  Big, rich and off-dry, this is powered by inte...
#
# ...

# %% [markdown]
# ### Dropping a column

# %%
#dropping a column
wine_data.drop(['date'],axis='columns',inplace=True)

# %%
wine_data
# Out:
#         Column1   country                                        description  \
# 0             0     Italy  Aromas include tropical fruit, broom, brimston...
# 1             1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2             2        US  Tart and snappy, the flavors of lime flesh and...
# 3             3        US  Pineapple rind, lemon pith and orange blossom ...
# 4             4        US  Much like the regular bottling from 2012, this...
# ...         ...       ...                                                ...
# 129966   129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967   129967        US  Citation is given as much as a decade of bottl...
# 129968   129968    France  Well-drained gravel soil gives this wine its c...
# 129969   129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970   129970    France  Big, rich and off-dry, this is powered by inte...
#
# ...

# %%
wine_data[pd.isnull(wine_data)['country']]
# Out:
#         Column1 country                                        description  \
# 913         913     NaN  Amber in color, this wine has aromas of peach ...
# 3131       3131     NaN  Soft, fruity and juicy, this is a pleasant, si...
# 4243       4243     NaN  Violet-red in color, this semisweet wine has a...
# 9509       9509     NaN  This mouthwatering blend starts with a nose of...
# 9750       9750     NaN  This orange-style wine has a cloudy yellow-gol...
# ...         ...     ...                                                ...
# 124176   124176     NaN  This Swiss red blend is composed of four varie...
# 129407   129407     NaN  Dry spicy aromas of dusty plum and tomato add ...
# 129408   129408     NaN  El Capricho is one of Uruguay's more consisten...
# 129590   129590     NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 129900   129900     NaN  This wine offers a delightful bouquet of black...
#
# ...

# %%
wine_data.country.fillna('unknown', inplace = True)

# %%
wine_data.loc[wine_data.country.isnull()]
# Out:
# Empty DataFrame
# Columns: [Column1, country, description, designation, points, price, province, region_1, region_2, taster_name, taster_twitter_handle, title, variety, winery]
# Index: []

# %% [markdown]
# ### Rename column or index names

# %%
#change points name to score
wine_data.rename(columns={'points':'score'})
# Out:
#         Column1   country                                        description  \
# 0             0     Italy  Aromas include tropical fruit, broom, brimston...
# 1             1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2             2        US  Tart and snappy, the flavors of lime flesh and...
# 3             3        US  Pineapple rind, lemon pith and orange blossom ...
# 4             4        US  Much like the regular bottling from 2012, this...
# ...         ...       ...                                                ...
# 129966   129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967   129967        US  Citation is given as much as a decade of bottl...
# 129968   129968    France  Well-drained gravel soil gives this wine its c...
# 129969   129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970   129970    France  Big, rich and off-dry, this is powered by inte...
#
# ...

# %%
wine_data.rename(index={0:'firstEntry',1:'secondEntry'})
# Out:
#              Column1   country  \
# firstEntry         0     Italy
# secondEntry        1  Portugal
# 2                  2        US
# 3                  3        US
# 4                  4        US
# ...              ...       ...
# 129966        129966   Germany
# 129967        129967        US
# 129968        129968    France
# 129969        129969    France
# 129970        129970    France
#
#                                                    description  \
# firstEntry   Aromas include tropical fruit, broom, brimston...
# secondEntry  This is ripe and fruity, a wine that is smooth...
# 2            Tart and snappy, the flavors of lime flesh and...
# 3            Pineapple rind, lemon pith and orange blossom ...
# 4            Much like the regular bottling from 2012, this...
# ...                                                        ...
# 129966       Notes of honeysuckle and cantaloupe sweeten th...
# 129967       Citation is given as much as a decade of bottl...
# ...
