# %%
import pandas as pd

# %%
#calling our data
wine_data = pd.read_csv('wine-data-Thu_2_6_22.csv')

# %%
wine_data
# Out:
#         Column1   country                                        description  \
# 0             0     Italy  Aromas include tropical fruit, broom, brimston...
# 1             1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2             2        US  Tart and snappy, the flavors of lime flesh and...
# 3             3        US  Pineapple rind, lemon pith and orange blossom ...
# 4             4        US  Much like the regular bottling from 2012, this...
# ...         ...       ...                                                ...
# 129966   129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967   129967        US  Citation is given as much as a decade of bottl...
# 129968   129968    France  Well-drained gravel soil gives this wine its c...
# 129969   129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970   129970    France  Big, rich and off-dry, this is powered by inte...
#
# ...

# %%
#to see the shape of our data
wine_data.shape
# Out:
# (129971, 14)

# %%
#to describe the data for us
wine_data.describe(include='all')
# Out:
#               Column1 country  \
# count   129971.000000  129908
# unique            NaN      43
# top               NaN      US
# freq              NaN   54504
# mean     64985.000000     NaN
# std      37519.540256     NaN
# min          0.000000     NaN
# 25%      32492.500000     NaN
# 50%      64985.000000     NaN
# 75%      97477.500000     NaN
# max     129970.000000     NaN
#
#                                               description designation  \
# count                                              129971       92506
# unique                                             119955       37976
# top     Ripe plum, game, truffle, leather and menthol ...     Reserve
# freq                                                    3        2009
# mean                                                  NaN         NaN
# std                                                   NaN         NaN
# min                                                   NaN         NaN
# ...

# %%
#calling out the null values
wine_data[wine_data.price.isnull()]
# Out:
#         Column1   country                                        description  \
# 0             0     Italy  Aromas include tropical fruit, broom, brimston...
# 13           13     Italy  This is dominated by oak and oak-driven aromas...
# 30           30    France  Red cherry fruit comes laced with light tannin...
# 31           31     Italy  Merlot and Nero d'Avola form the base for this...
# 32           32     Italy  Part of the extended Calanìca series, this Gri...
# ...         ...       ...                                                ...
# 129844   129844     Italy  Doga delle Clavule is a neutral, mineral-drive...
# 129860   129860  Portugal  This rich wine has a firm structure as well as...
# 129863   129863  Portugal  This mature wine that has 50% Touriga Nacional...
# 129893   129893     Italy  Aromas of passion fruit, hay and a vegetal not...
# 129964   129964    France  Initially quite muted, this wine slowly develo...
#
# ...

# %%
#replacing the NaN values
wine_data.price.fillna(35, inplace = True)

# %%
wine_data[wine_data.price.isnull()]
# Out:
# Empty DataFrame
# Columns: [Column1, country, description, designation, points, price, province, region_1, region_2, taster_name, taster_twitter_handle, title, variety, winery]
# Index: []

# %%
wine_data
# Out:
#         Column1   country                                        description  \
# 0             0     Italy  Aromas include tropical fruit, broom, brimston...
# 1             1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2             2        US  Tart and snappy, the flavors of lime flesh and...
# 3             3        US  Pineapple rind, lemon pith and orange blossom ...
# 4             4        US  Much like the regular bottling from 2012, this...
# ...         ...       ...                                                ...
# 129966   129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967   129967        US  Citation is given as much as a decade of bottl...
# 129968   129968    France  Well-drained gravel soil gives this wine its c...
# 129969   129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970   129970    France  Big, rich and off-dry, this is powered by inte...
#
# ...

# %%
#calling out the tail of our data
wine_data.tail()
# Out:
#         Column1  country                                        description  \
# 129966   129966  Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967   129967       US  Citation is given as much as a decade of bottl...
# 129968   129968   France  Well-drained gravel soil gives this wine its c...
# 129969   129969   France  A dry style of Pinot Gris, this is crisp with ...
# 129970   129970   France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price province  \
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0    Mosel
# 129967                                     NaN      90   75.0   Oregon
# 129968                                   Kritt      90   30.0   Alsace
# 129969                                     NaN      90   32.0   Alsace
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace
#
#        region_1      region_2         taster_name taster_twitter_handle  \
# ...

# %%
#Using iloc to call out the price column
wine_data.iloc[:,[5]]
# Out:
#         price
# 0        35.0
# 1        15.0
# 2        14.0
# 3        13.0
# 4        65.0
# ...       ...
# 129966   28.0
# 129967   75.0
# 129968   30.0
# 129969   32.0
# 129970   21.0
#
# [129971 rows x 1 columns]

# %%
#calling out the first 14 rows of our data
wine_data.head(14)
# Out:
#     Column1   country                                        description  \
# 0         0     Italy  Aromas include tropical fruit, broom, brimston...
# 1         1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2         2        US  Tart and snappy, the flavors of lime flesh and...
# 3         3        US  Pineapple rind, lemon pith and orange blossom ...
# 4         4        US  Much like the regular bottling from 2012, this...
# 5         5     Spain  Blackberry and raspberry aromas show a typical...
# 6         6     Italy  Here's a bright, informal red that opens with ...
# 7         7    France  This dry and restrained wine offers spice in p...
# 8         8   Germany  Savory dried thyme notes accent sunnier flavor...
# 9         9    France  This has great depth of flavor with its fresh ...
# 10       10        US  Soft, supple plum envelopes an oaky structure ...
# 11       11    France  This is a dry wine, very spicy, with a tight, ...
# ...

# %%
wine_data[wine_data.points.isnull()]
# Out:
# Empty DataFrame
# Columns: [Column1, country, description, designation, points, price, province, region_1, region_2, taster_name, taster_twitter_handle, title, variety, winery]
# Index: []

# %%
#calling out the taster names and twitter handles who tasted in Portugal
wine_data.loc[wine_data.country == 'Portugal',['taster_name','taster_twitter_handle']]
# Out:
#        taster_name taster_twitter_handle
# 1       Roger Voss            @vossroger
# 79      Roger Voss            @vossroger
# 151     Roger Voss            @vossroger
# 157     Roger Voss            @vossroger
# 203     Roger Voss            @vossroger
# ...            ...                   ...
# 129863  Roger Voss            @vossroger
# 129864  Roger Voss            @vossroger
# 129865  Roger Voss            @vossroger
# 129901  Roger Voss            @vossroger
# 129960  Roger Voss            @vossroger
#
# [5691 rows x 2 columns]

# %%
#calling out the taster names and twitter handles who tasted in France
wine_data.loc[wine_data.country == 'France',['taster_name','taster_twitter_handle']]
# Out:
#        taster_name taster_twitter_handle
# 7       Roger Voss            @vossroger
# 9       Roger Voss            @vossroger
# 11      Roger Voss            @vossroger
# 30      Roger Voss            @vossroger
# 42      Roger Voss            @vossroger
# ...            ...                   ...
# 129964  Roger Voss            @vossroger
# 129965  Roger Voss            @vossroger
# 129968  Roger Voss            @vossroger
# 129969  Roger Voss            @vossroger
# 129970  Roger Voss            @vossroger
#
# [22093 rows x 2 columns]

# %%
#another way for calling out the taster names and twitter handles who tasted in Portugal
country_1 = wine_data[['taster_name','taster_twitter_handle','country']]
country_1.loc[wine_data.country == 'Portugal']
# Out:
#        taster_name taster_twitter_handle   country
# 1       Roger Voss            @vossroger  Portugal
# 79      Roger Voss            @vossroger  Portugal
# 151     Roger Voss            @vossroger  Portugal
# 157     Roger Voss            @vossroger  Portugal
# 203     Roger Voss            @vossroger  Portugal
# ...            ...                   ...       ...
# 129863  Roger Voss            @vossroger  Portugal
# 129864  Roger Voss            @vossroger  Portugal
# 129865  Roger Voss            @vossroger  Portugal
# 129901  Roger Voss            @vossroger  Portugal
# 129960  Roger Voss            @vossroger  Portugal
#
# [5691 rows x 3 columns]

# %%
#another way for calling out the taster names and twitter handles who tasted in France 
for index,row in wine_data.iterrows():
    if row.country == 'France':
        print(row.taster_name,row.taster_twitter_handle,row.country)
# Out:
# Roger Voss @vossroger France
# Roger Voss @vossroger France
# Roger Voss @vossroger France
# Roger Voss @vossroger France
# Roger Voss @vossroger France
# Roger Voss @vossroger France
# Roger Voss @vossroger France
# Roger Voss @vossroger France
# Roger Voss @vossroger France
# Roger Voss @vossroger France
# Roger Voss @vossroger France
# Roger Voss @vossroger France
# Roger Voss @vossroger France
# Roger Voss @vossroger France
# Roger Voss @vossroger France
# nan nan France
# nan nan France
# nan nan France
# nan nan France
# nan nan France
# Joe Czerwinski @JoeCz France
# nan nan France
# nan nan France
# nan nan France
# Roger Voss @vossroger France
# Roger Voss @vossroger France
# Roger Voss @vossroger France
# Roger Voss @vossroger France
# Roger Voss @vossroger France
# Joe Czerwinski @JoeCz France
# Joe Czerwinski @JoeCz France
# Roger Voss @vossroger France
# Roger Voss @vossroger France
# Roger Voss @vossroger France
# Roger Voss @vossroger France
# ...

# %%
#another way for calling out the taster names and twitter handles who tasted in Portugal
country_1.loc[wine_data.country == 'France']
# Out:
#        taster_name taster_twitter_handle country
# 7       Roger Voss            @vossroger  France
# 9       Roger Voss            @vossroger  France
# 11      Roger Voss            @vossroger  France
# 30      Roger Voss            @vossroger  France
# 42      Roger Voss            @vossroger  France
# ...            ...                   ...     ...
# 129964  Roger Voss            @vossroger  France
# 129965  Roger Voss            @vossroger  France
# 129968  Roger Voss            @vossroger  France
# 129969  Roger Voss            @vossroger  France
# 129970  Roger Voss            @vossroger  France
#
# [22093 rows x 3 columns]
